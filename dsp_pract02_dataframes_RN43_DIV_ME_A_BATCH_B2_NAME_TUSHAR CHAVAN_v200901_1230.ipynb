# %% [markdown]
# # DSLab: Practical 2: R Dataframes etc

# %% [markdown]
# **Instructions:**
# 1. **Complete** the practical jupyter notebook:
#     - Write code in code cells provided between the
#       marker comments.
#     - Make sure that you have executed your code and output of
#       your code is visible below the code cell
#
#
# 2. **VVIMP Instructions for writing code:**
#     - **At the Start: Must write your Roll No & GRN as per instructions**
#         + Enter above values as asked in the appropriate
#           cell below
#         + Run the cell
#         + Preferably run ALL CELLS by going to the menu:
#           Cell > Run All
#     - **Generate Problem statements**: Problem statements
#         may need to be generated by running some code cells.
#       Do this as instructed.
#       Typically, first comment line in such cells says this:
#       "Run this code cell to generate problem statement"
#     - **Write your code** only in the **Write your code here**
#       blocks
#
#
# 2. **Rename** the .ipynb file as follows:
#     + Write 2 digit roll no **in filename** by replacing XX in
#       RNXX, eg RN05.
#       Note: Write roll no 5 as 05 and not just 5
#     + Write your DIV as, eg, CHA
#     + Write your batch as, eg, B2
#     + Write your name in place of YYY in NAME_YYY
#
#
# 3. **Upload (submit)** following two files to Google
#    Classroom:
#     1. The jupyter notebook file .ipynb
#     2. A single html file with same name (ie only extension changes to .html)
#         - Those having problems in creation of html need not submit this file

# %% [markdown]
# ## Enter your information
# **Imp: Run the code cell below, after entering your information as explained there**

# %%
# VVIMP: Fill up & Run this code cell first before starting with later cells
# -------------------------------
# Start of: Write your code here
# -------------------------------
# Enter your roll number, gr no & name below
# Do not change variable names
rn <- 43
grn <- 11910702
my_name <- "Tushar Vilas Chavan"
# -------------------------------
# End of: Write your code here
# -------------------------------
sprintf("My Roll Number is: %s", rn)
sprintf("My GR Number is  : %s", grn)
sprintf("Name is  : %s", my_name)
# Out:
# [1] "My Roll Number is: 43"
# [1] "My GR Number is  : 11910702"
# [1] "Name is  : Tushar Vilas Chavan"

# %% [markdown]
# ## Dataframes

# %% [markdown]
# ### Problem 1 : Create dataframe and access it
# (Run following code cell to generate problem statement)

# %%
# Run this code cell to generate problem statement
# if (rn==0 | grn == 0) {
#     print('Enter both your roll & gr no above before proceeding');
#     print('If you have already done so, run all cells (click Cell > Run All )')
#     break}

sprintf("If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All")
sprintf("Roll No: %s, GRN: %s, Name: %s ", rn,grn,my_name)
set.seed(rn)
n_elem = 6
x <- runif(n_elem,min=0, max= 100)
y <- runif(n_elem,min=0, max= 100)
z <- runif(n_elem,min=0, max= 100)

print("+++++++++++++++++++++++++++++++++")
print("  Start of: Problem 1 Statement  ")
print("+++++++++++++++++++++++++++++++++")
sprintf("-------(1a)-------")
sprintf("Create a dataframe with the following columns")
print(paste(c("<Your first name> = ",round(x,digits=0)),collapse=" "))
print(paste(c("<Your surname> = ",round(y,digits=0)),collapse=" "))
print(paste(c("<Your hometown> = ",round(z,digits=0)),collapse=" "))
sprintf("-------(1b)-------")
sprintf("Print out the dataframe")

sprintf("-------(1c)-------")
sprintf("i.  Print the column named with your surname: Use $")
sprintf("ii.  Print the column named with your first name: Use$")
sprintf("iii. Print row %.0f", runif(1,min=2,max=n_elem))
sprintf("iv.  Print the element: (%.0f, %.0f)", runif(1,min=1,max=3), runif(1,min=1,max=n_elem))

sprintf("-------(1d)-------")
sprintf("Create a df with rows %.0f & %.0f and print it",runif(1,min=1,max=n_elem), runif(1,min=1,max=n_elem) )
print("+++++++++++++++++++++++++++++++++")
print("    End of: Problem 1 Statement  ")
print("+++++++++++++++++++++++++++++++++")
# Out:
# [1] "If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All"
# [1] "Roll No: 43, GRN: 11910702, Name: Tushar Vilas Chavan "
# [1] "+++++++++++++++++++++++++++++++++"
# [1] "  Start of: Problem 1 Statement  "
# [1] "+++++++++++++++++++++++++++++++++"
# [1] "-------(1a)-------"
# [1] "Create a dataframe with the following columns"
# [1] "<Your first name> =  49 91 6 71 31 54"
# [1] "<Your surname> =  68 51 18 87 39 16"
# [1] "<Your hometown> =  65 26 48 67 25 21"
# [1] "-------(1b)-------"
# [1] "Print out the dataframe"
# [1] "-------(1c)-------"
# [1] "i.  Print the column named with your surname: Use $"
# [1] "ii.  Print the column named with your first name: Use$"
# [1] "iii. Print row 2"
# [1] "iv.  Print the element: (1, 6)"
# [1] "-------(1d)-------"
# [1] "Create a df with rows 5 & 2 and print it"
# [1] "+++++++++++++++++++++++++++++++++"
# [1] "    End of: Problem 1 Statement  "
# ...

# %%
#sprintf("If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All")
sprintf("Roll No: %s, GRN: %s, Name: %s ", rn,grn,my_name)
# -------------------------------
# Start of: Write your code here
# -------------------------------
sprintf(" Dataframe having column names as Name, Surname and Town name:  both #1a and #1b")
df <- data.frame(Tushar = c(49,91,6,71,31,54), Chavan = c(68,51,18,87,39,16), Aurangabad=c( 65,26,48,67,25,21)) 
df #1a
sprintf("Coumn having Surname as head:  #1c i")
unique(df$Chavan)
sprintf("Coumn having Name as head:  #1c ii")
unique(df$Tushar)
sprintf(" The Row 2 in dataset:   #1c iii")
df2<-df[2,]
df2
sprintf("The elemet=n[1,6]:   #1c  iv")
df[1,6]
df_2 <- df[5,]
sprintf("Dataframe with rows 5 and 2 : ")
df3 <- rbind(r1= c(df_2), r2=c(df2))
df3

# -------------------------------
# End of: Write your code here
# -------------------------------
# Out:
# [1] "Roll No: 43, GRN: 11910702, Name: Tushar Vilas Chavan "
# [1] " Dataframe having column names as Name, Surname and Town name:  both #1a and #1b"
#   Tushar Chavan Aurangabad
# 1 49     68     65
# 2 91     51     26
# 3  6     18     48
# 4 71     87     67
# 5 31     39     25
# 6 54     16     21
# [1] "Coumn having Surname as head:  #1c i"
# [1] 68 51 18 87 39 16
# [1] "Coumn having Name as head:  #1c ii"
# [1] 49 91  6 71 31 54
# [1] " The Row 2 in dataset:   #1c iii"
#   Tushar Chavan Aurangabad
# 2 91     51     26
# [1] "The elemet=n[1,6]:   #1c  iv"
# NULL
# [1] "Dataframe with rows 5 and 2 : "
#    Tushar Chavan Aurangabad
# r1 31     39     25
# r2 91     51     26

# %% [markdown]
# ### Problem 2: mpg dataset: Summaries
# (Run following code cell to generate problem statement)

# %%
# Run this code cell to generate problem statement
sprintf("If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All")
sprintf("Roll No: %s, GRN: %s, Name: %s ", rn,grn,my_name)

print("+++++++++++++++++++++++++++++++++")
print("  Start of: Problem 2 Statement  ")
print("+++++++++++++++++++++++++++++++++")
library(tidyverse)

print("2a) Print out the dimension of the mpg dataset")
print("2b) Print out the names of columns in mpg")
print("2c) List all manufacturers")
print("   Each manufacturer should appear only once in the list. hint: use the unique function)")
print("2d) List all unique fuel types")
print("+++++++++++++++++++++++++++++++++")
print("  End of: Problem 2 Statement  ")
print("+++++++++++++++++++++++++++++++++")
# Out:
# [1] "If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All"
# [1] "Roll No: -100, GRN: -100, Name: I havent entered any info really! "
# [1] "+++++++++++++++++++++++++++++++++"
# [1] "  Start of: Problem 2 Statement  "
# [1] "+++++++++++++++++++++++++++++++++"
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# ...

# %%
#sprintf("If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All")
#sprintf("Roll No: %s, GRN: %s, Name: %s ", rn,grn,my_name)
library(tidyverse)
head(mpg)
# -------------------------------
# Start of: Write your code here
# -------------------------------
sprintf("The dimensions of the dataset mpg is :");dim(mpg) #2a
sprintf("The names of columns in the mpg dataset are: #2b")
names(mpg) #2b
sprintf("The names of manufacturers in the mpg dataset are: #2c")
unique(mpg$manufacturer) #2c
sprintf("The names of fuels in the mpg dataset are: #2d")
unique(mpg$fl)  #2d


# -------------------------------
# End of: Write your code here
# -------------------------------
# Out:
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.3.2     v purrr   0.3.2
# v tibble  3.0.3     v dplyr   1.0.2
# v tidyr   0.8.3     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"Warning message:
# "package 'tibble' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# ...

# %% [markdown]
# ### Problem 3: mpg dataset
# (Run following cell to generate problem statement)

# %%
# Run this code cell to generate problem statement
#sprintf("If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All")
sprintf("Roll No: %s, GRN: %s, Name: %s ", rn,grn,my_name)

print("+++++++++++++++++++++++++++++++++")
print("  Start of: Problem 3 Statement  ")
print("+++++++++++++++++++++++++++++++++")
library(tidyverse)
set.seed(rn)
print('In following, ignore if some column names are repeated')
sprintf("3a) How many cars are there in the mpg dataset?")
nms <- names(mpg); nm2 <- sample(nm1[(nm1!='hwy') & (nm1 !='cty')],2)
nms <- c('hwy',nm2)
sprintf("3b) Create a data frame with following columns:")
sprintf("%s ", nms)
nm2 <- sample(nm1[(nm1!='hwy') & (nm1 !='cty')],2)
nms <- c('cty',nm2)
sprintf("3c) Create a data frame with following columns:")
sprintf("%s ", nms)

sprintf("3d) Create a data frame with first %.0f rows & print 1st 6 (using head)", runif(1,min=10, max=100))
sprintf("3e) Create a data frame with row numbers given below and print it:")
sample(1:100,4)

print("+++++++++++++++++++++++++++++++++")
print("  End of: Problem 3 Statement  ")
print("+++++++++++++++++++++++++++++++++")
# Out:
# [1] "Roll No: 43, GRN: 11910702, Name: Tushar Vilas Chavan "
# [1] "+++++++++++++++++++++++++++++++++"
# [1] "  Start of: Problem 3 Statement  "
# [1] "+++++++++++++++++++++++++++++++++"
# [1] "In following, ignore if some column names are repeated"
# [1] "3a) How many cars are there in the mpg dataset?"
# [1] "3b) Create a data frame with following columns:"
# [1] "hwy "  "fl "   "year "
# [1] "3c) Create a data frame with following columns:"
# [1] "cty "   "cyl "   "model "
# [1] "3d) Create a data frame with first 59 rows & print 1st 6 (using head)"
# [1] "3e) Create a data frame with row numbers given below and print it:"
# [1] 90 56 88 77
# [1] "+++++++++++++++++++++++++++++++++"
# [1] "  End of: Problem 3 Statement  "
# [1] "+++++++++++++++++++++++++++++++++"

# %%
#sprintf("If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All")
sprintf("Roll No: %s, GRN: %s, Name: %s ", rn,grn,my_name)
library(tidyverse)
# -------------------------------
# Start of: Write your code here
# -----------------------------
df_1 <- select(mpg, model)
sprintf("There are total %s cars in the mpg. #3a",nrow(df_1))
sprintf("Dataframe with Columns fl,hwy and year:   #3b")
df2 <- select(mpg, fl, hwy, year)
head(df2)
sprintf("Dataframe with Columns cty,cyl and model:   #3c")
df3 <- select(mpg, cty, cyl, model)
head(df3)
sprintf("The first 59 rows in mpg are as follows :   #3d")
df4 <- mpg[1:59,1:11]
head(df4)
sprintf("The rows given 90,56,88,77 are as follows")
a_90 <-c(mpg[90,1:11]);b_56<-c(mpg[56,1:11]);c_88<- c(mpg[88,1:11]);d_77<-c(mpg[77,1:11])
df5 <- rbind(a_90,b_56,c_88,d_77)
df5

# -------------------------------
# End of: Write your code here
# -------------------------------
# Out:
# [1] "If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All"
# [1] "Roll No: 43, GRN: 11910702, Name: Tushar Vilas Chavan "
# [1] "There are total 234 cars in the mpg. #3a"
# [1] "Dataframe with Columns fl,hwy and year:   #3b"
#   fl hwy year
# 1 p  29  1999
# 2 p  29  1999
# 3 p  31  2008
# 4 p  30  2008
# 5 p  26  1999
# 6 p  26  1999
# [1] "Dataframe with Columns cty,cyl and model:   #3c"
#   cty cyl model
# 1 18  4   a4
# 2 21  4   a4
# 3 20  4   a4
# 4 21  4   a4
# 5 16  6   a4
# 6 18  6   a4
# [1] "The first 59 rows in mpg are as follows :   #3d"
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# ...

# %% [markdown]
# ### Problem 4: Subsetting mpg dataset
# (Run following cell to generate problem statement)

# %%
# Run this code cell to generate problem statement
sprintf("If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All")
sprintf("Roll No: %s, GRN: %s, Name: %s ", rn,grn,my_name)

print("+++++++++++++++++++++++++++++++++")
print("  Start of: Problem 4 Statement  ")
print("+++++++++++++++++++++++++++++++++")
library(tidyverse)
set.seed(rn)
sprintf("4a) How many cars by the manufacturer \"%s\" are there in mpg?", sample(unique(mpg$manufacturer),1))
manuf <- sample(unique(mpg$manufacturer),2)
sprintf("4b) How many cars by the following manufacturers combined?:")
sprintf("%s ", manuf)
sprintf("4c) How many cars using diesel?")
fuels <- sample(unique(mpg$fl),3)
sprintf("4d) Create a dataframe of cars using the following fuels and print out first 6 rows (using head())" )
sprintf("%s ", fuels)
sprintf("4e) What is the city average of all cars in mpg?")
cls <- sample(unique(mpg$class),2)
sprintf("4f) What is the highway average of all cars of the following classes taken together?")
sprintf("%s ", cls)
sprintf("4g) How many cars with cylinders more than or equal to %s ?", sample(unique(mpg$cyl),1))
sprintf("4h) Find min and max city mileage (mpg) of all cars")
sprintf("4i) Find min and max highway mileage (mpg) of all cars")
sprintf("4j) How many cars have city mileage below %s ?", sample((15:20),1))

print("+++++++++++++++++++++++++++++++++")
print("  End of: Problem 4 Statement  ")
print("+++++++++++++++++++++++++++++++++")
# Out:
# [1] "If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All"
# [1] "Roll No: 43, GRN: 11910702, Name: Tushar Vilas Chavan "
# [1] "+++++++++++++++++++++++++++++++++"
# [1] "  Start of: Problem 4 Statement  "
# [1] "+++++++++++++++++++++++++++++++++"
# [1] "4a) How many cars by the manufacturer \"pontiac\" are there in mpg?"
# [1] "4b) How many cars by the following manufacturers combined?:"
# [1] "land rover " "ford "
# [1] "4c) How many cars using diesel?"
# [1] "4d) Create a dataframe of cars using the following fuels and print out first 6 rows (using head())"
# [1] "c " "r " "p "
# [1] "4e) What is the city average of all cars in mpg?"
# [1] "4f) What is the highway average of all cars of the following classes taken together?"
# [1] "midsize " "minivan "
# [1] "4g) How many cars with cylinders more than or equal to 8 ?"
# [1] "4h) Find min and max city mileage (mpg) of all cars"
# ...

# %%
#sprintf("If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All")
sprintf("Roll No: %s, GRN: %s, Name: %s ", rn,grn,my_name)
library(tidyverse)
# -------------------------------
# Start of: Write your code here
# ------------------------------
df <- filter(mpg, manufacturer == 'pontiac')
sprintf("There are total %s 'pontaic' cars in the mpg.  #4a",nrow(df))  #4a
df2 <- filter(mpg, manufacturer == 'land rover' | manufacturer == 'ford')
sprintf("There are total %s 'land rover', 'ford' combined  cars in the mpg. #4b",nrow(df2))  #4b
df3 <- filter(mpg, fl == 'd')
sprintf("There are total %s diesel cars in the mpg.  #4c",nrow(df3)) #4c
df4 <- filter(mpg, fl == 'c' | fl =='p' | fl == 'r')
head(df4) #4d
avg_mil <- summarise(mpg, avg=mean(cty, na.rm=TRUE) ) 
sprintf("The City average milage of the cars in mpg is %s  #4e", avg_mil) #4e
df5 <- filter(mpg, class == "midsize" | class =='minivan')
cla <- summarise(df5, avg=mean(hwy, na.rm=TRUE))
sprintf("The Highway average milage of the cars in mpg is %s  #4f", cla) #4f
df6 <- filter(mpg, cyl >=8)
sprintf(" There are total %s cars having 8 or more than 8 cylinders in mpg.  #4g",nrow(df6)) #4g
df7 <- select(mpg, cty, hwy)
sprintf(" The max and min milage of cars in mpg are %s and %s repspectively.  #4h",max(df7),min(df7)) #4h
df8 <- select(mpg, hwy)
sprintf(" The max and min  Highway milage of cars in mpg are %s and %s repspectively.  #4i",max(df8),min(df8)) #4i
df9 <- filter(mpg, cty < 16)
sprintf(" There are total %s cars having city milage less than 16 in mpg.  #4j",nrow(df9))  #4j



  
# -------------------------------
# End of: Write your code here
# -------------------------------
# Out:
# [1] "If the following are not your roll no, gr no & name, change at top under the cell titled Enter Your Information and do Cell > Run All"
# [1] "Roll No: 43, GRN: 11910702, Name: Tushar Vilas Chavan "
# [1] "There are total 5 'pontaic' cars in the mpg.  #4a"
# [1] "There are total 29 'land rover', 'ford' combined  cars in the mpg. #4b"
# [1] "There are total 5 diesel cars in the mpg.  #4c"
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact
# [1] "The City average milage of the cars in mpg is 16.8589743589744  #4e"
# ...

# %%
library(readxl)
library(tidyverse)
data_cpi <- read_excel("All_India_Index_july2019_20Aug2020.xlsx")
data(data_cpi)
data_cpi[,c(4:30)] <- sapply(data_cpi[,c(4:30)],as.numeric)
names(data_cpi)
#################<Machine Learning>########################

###################################################################
library(lasso2)
#lm.lasso <- l1ce(General_index ~ Cereals_and_products + Meat_and_fish+ Egg + Milk_and_products + Oils_and_fats + Fruits
#+ Vegetables + Pulses_and_products + Sugar_and_Confectionery + Spices + Non_alcoholic_beverages + Prepared_meals_snacks_sweets_etc
 #+ Food_and_beverages + Pan_tobacco_and_intoxicants + Clothing + Footwear + Clothing_and_footwear + Housing + Fuel_and_light + Household_goods_and_services +
 #Transport_and_communication + Recreation_and_amusement + Education + Personal_care_and_effects + Miscellaneous , data=data_cpi)
#summary(lm.lasso)$coefficients
# ###########     Personal_care_and_effects | Recreation_and_amusement | Clothing_and_footwear == 0 ####################



#lm.lasso_2 <- l1ce(General_index ~ Cereals_and_products + Meat_and_fish+ Egg + Milk_and_products + Oils_and_fats + Fruits
#+ Vegetables + Pulses_and_products + Sugar_and_Confectionery + Spices + Non_alcoholic_beverages + Prepared_meals_snacks_sweets_etc
 #+ Food_and_beverages + Pan_tobacco_and_intoxicants + Clothing + Footwear + Housing + Fuel_and_light + Household_goods_and_services +
# Transport_and_communication  + Education + Miscellaneous , data=data_cpi)
#summary(lm.lasso_2)$coefficients
# Household_goods_and_services = 0


#lm.lasso_3 <- l1ce(General_index ~ Cereals_and_products + Meat_and_fish+ Egg + Milk_and_products + Oils_and_fats + Fruits
#+ Vegetables + Pulses_and_products + Sugar_and_Confectionery + Spices + Non_alcoholic_beverages + Prepared_meals_snacks_sweets_etc
# + Food_and_beverages + Pan_tobacco_and_intoxicants + Clothing + Footwear + Housing + Fuel_and_light + Transport_and_communication  + Education + Miscellaneous , data=data_cpi)
#summary(lm.lasso_3)$coefficients
#Milk_and_products =0 


lm.lasso_4 <- l1ce(General_index ~ Cereals_and_products + Meat_and_fish+ Egg + Oils_and_fats + Fruits
+ Vegetables + Pulses_and_products + Sugar_and_Confectionery + Spices + Non_alcoholic_beverages + Prepared_meals_snacks_sweets_etc
 + Food_and_beverages + Pan_tobacco_and_intoxicants + Clothing + Footwear + Housing + Fuel_and_light + Transport_and_communication  + Education + Miscellaneous , data=data_cpi)
summary(lm.lasso_4)$coefficients

# ---------------------------------------------Final Lesso method------------------------
# Number of Factors affecting General Index 



# Value	Std. Error	Z score	Pr(>|Z|)
# (Intercept)	-2.537561666	1.308545355	-1.9392233	5.247415e-02
# Cereals_and_products	-0.054969497	0.021204682	-2.5923282	9.532877e-03
# Meat_and_fish	-0.012514225	0.009360659	-1.3368957	1.812567e-01
# Egg	-0.005711679	0.004407323	-1.2959520	1.949920e-01
# Oils_and_fats	0.114905089	0.015867370	7.2415964	4.434231e-13
# Fruits	-0.018424927	0.007116109	-2.5891856	9.620323e-03
# Vegetables	-0.023187632	0.007667463	-3.0241597	2.493248e-03
# Pulses_and_products	-0.012683250	0.002978519	-4.2582410	2.060418e-05
# Sugar_and_Confectionery	-0.011458979	0.002940872	-3.8964565	9.761033e-05
# Spices	-0.023692067	0.016787481	-1.4112937	1.581580e-01
# Non_alcoholic_beverages	0.015954527	0.033659828	0.4739931	6.355048e-01
# Prepared_meals_snacks_sweets_etc	-0.087245503	0.037024117	-2.3564506	1.845052e-02
# Food_and_beverages	0.588288078	0.058974955	9.9752188	0.000000e+00
# Pan_tobacco_and_intoxicants	-0.003444400	0.014297849	-0.2409034	8.096300e-01
# Clothing	0.180593596	0.045709657	3.9508849	7.786276e-05
# Footwear	-0.016392562	0.036011577	-0.4552026	6.489635e-01
# Housing	0.209118003	0.015339637	13.6325266	0.000000e+00
# Fuel_and_light	0.013247354	0.010209493	1.2975526	1.944411e-01
# Transport_and_communication	0.051040220	0.022865755	2.2321686	2.560382e-02
# Education	0.059180505	0.027106817	2.1832333	2.901863e-02
# Miscellaneous	0.067020186	0.053405576	1.2549286	2.095047e-01

# --------------------------------------------------------------------------------------
# Equation can be written as :-
# General_index = -2.537561666 (y-intercept) + Cereals_and_products*-0.054969497 + Meat_and_fish	-0.012514225 + Egg	-0.005711679 + 
#                  Oils_and_fats	0.114905089 + Fruits	-0.018424927 + Vegetables	-0.023187632 + Pulses_and_products	-0.012683250
#                  Sugar_and_Confectionery	-0.011458979 + Spices	-0.023692067 +  Non_alcoholic_beverages	0.015954527 + Prepared_meals_snacks_sweets_etc	-0.087245503
#                  Food_and_beverages	0.588288078 + Pan_tobacco_and_intoxicants	-0.003444400 + Clothing	0.180593596 + Footwear	-0.016392562
#                  Housing	0.209118003 +  Fuel_and_light	0.013247354 + Transport_and_communication	0.051040220 +  Miscellaneous	0.067020186







#########################################################
model <- lm(data_cpi$General_index ~ data_cpi$Health )
plot(y = data_cpi$General_index, x = data_cpi$Health, xlab = "CPI of Health",
 ylab = "CPI in General", main = "CPI Comparison")
abline(a = coef(model[1]), b = coef(model)[2], lty = 2)
split_size = 0.8
sample_size = floor(split_size * nrow(data_cpi))
set.seed(123)
train_indices <- sample(seq_len(nrow(data_cpi)), size = sample_size)
train <- data_cpi[train_indices, ] #training data
test <- data_cpi[-train_indices, ] #testing data
model2 <- lm(General_index ~ Health, data = train)
new.data <- data.frame(Health = test$Health)
nrow(new.data)
test$output <- predict(model2, new.data)
test$output
er <- sqrt(sum(test$General_index - test$output)^2/nrow(test))
sprintf("The Error in the model is %f ", er)
# Out:
# Warning message in data(data_cpi):
# "data set 'data_cpi' not found"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# "NAs introduced by coercion"Warning message in lapply(X = X, FUN = FUN, ...):
# ...
